# %%
import numpy as np
import pandas as pd

# %%
import datetime

# %% [markdown]
# 엑셀 자체에서 작업을 따로 해주어야할듯

# %%
movieInfo_total = pd.read_excel("movieInfo_total.xlsx")

# %%
movieInfo_total
# Out:
#         rank           movieNm   directorNm                       producerNm  \
# 0          1                명량          김한민                        (주)빅스톤픽쳐스
# 1          2              극한직업          이병헌  (주)어바웃필름,영화사 해그림 주식회사,씨제이이앤엠(주)
# 2          3         신과함께-죄와 벌          김용화           리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 3          4              국제시장          윤제균              (주)제이케이필름,씨제이이앤엠(주)
# 4          5        어벤져스: 엔드게임  안소니 루소,조 루소                              NaN
# 5          6               아바타      제임스 카메론                    이십세기폭스필름코퍼레이션
# 6          7               베테랑          류승완                  (주)외유내강,(주)필름케이
# 7          8                괴물          봉준호                        영화사청어람(주)
# 8          9               도둑들          최동훈                         (주)케이퍼필름
# 9         10           7번방의 선물          이환경              (주)화인웍스,(주)씨엘엔터테인먼트
# 10        11                암살          최동훈                         (주)케이퍼필름
# ...
